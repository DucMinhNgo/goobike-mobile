# %% [markdown]
# # Call before run android (yarn start)
# export ANDROID_HOME=$HOME/Library/Android/sdk
# export PATH=$PATH:$ANDROID_HOME/emulator
# export PATH=$PATH:$ANDROID_HOME/tools
# export PATH=$PATH:$ANDROID_HOME/tools/bin
# export PATH=$PATH:$ANDROID_HOME/platform-tools
#
# # Call before run xcode
# https://github.com/aws-samples/aws-sdk-js-tests/issues/62
#
# sudo xcode-select -s /Applications/Xcode.app/Contents/Developer
#
# brew install cocoapods
# pod -v
# pod cache clean --all
#
# pod install

# %% [markdown]
# # Install Sdk
# ![image.png](attachment:image.png)

# %% [markdown]
# # Build apk
# cd android
# ./gradlew assembleRelease
# # Locate the APK
#
# Once the build process completes, you can find the generated APK in the 'android/app/build/outputs/apk/release directory'.
# The APK file will be named something like app-release.apk.

# %% [markdown]
# # Xcode version
# https://xcodereleases.com/
